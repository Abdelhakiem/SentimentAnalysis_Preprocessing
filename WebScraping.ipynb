# %% [markdown]
# # Scraping Web Scraping on Reddit WallstreetBets

# %%
from selenium import webdriver
from collections import Counter
import numpy as np
from datetime import date,timedelta
import datetime
from dateutil.parser import parse
import requests
from selenium.webdriver.common.by import By

def grab_html():
     url = 'https://www.reddit.com/r/wallstreetbets/search/?q=flair%3A%22Daily%20Discussion%22&restrict_sr=1&sort=new'
     driver = webdriver.Chrome(executable_path=r'c:\chromedriver.exe')
     driver.get(url)
     return driver
def grab_link(driver):
	yesterday =datetime.date.today()-timedelta(days=2)
	links =driver.links =driver.find_elements_by_xpath('//*[@class="_eYtD2XCVieq6emjKBH3m"]')

	for a in links:
		print(a.text)

		if a.text.startswith('Weekend'):
			weekend_date = a.text.split(' ')
			parsed_date = weekend_date[-3] + ' ' + weekend_date[-2].split("-")[1] + weekend_date[-1]
			parsed = parse(parsed_date)
			saturday = weekend_date[-3] + ' ' +  str(int(weekend_date[-2].split("-")[1].replace(',','')) - 1) + ' ' + weekend_date[-1]
			if parse(str(yesterday)) == parsed:
				link = a.find_elements_by_xpath('../..').get_attribute('href')
			elif parse(str(yesterday)) == parse(str(saturday)):
				link = a.find_elements_by_xpath('../..').get_attribute('href')
		if a.text.startswith('Daily Discussion Thread'):
			date = "".join(a.text.split(' ')[-3:])
			parsed = parse(date)
			if parse(str(yesterday)) == parsed:
				link = a.find_elements_by_xpath('../..').get_attribute('href')
	stock_link = link.split('/')[-3]
	driver.close()
	return stock_link

def grab_commentid_list(stock_link):
    html = requests.get(f'https://api.pushshift.io/reddit/submission/comment_ids/{stock_link}')
    raw_comment_list = html.json()
    return raw_comment_list
def grab_stocklist():
	stocks_list=['MMM','ABT','ABBV','ACN','ATVI','AYI','ADBE','AMD','AAP','AES','AET',
		'AMG','AFL','A','APD','AKAM','ALK','ALB','ARE','ALXN','ALGN','ALLE',
		'AGN','ADS','LNT','ALL','GOOGL','GOOG','MO','AMZN','AEE','AAL','AEP',
		'AXP','AIG','AMT','AWK','AMP','ABC','AME','AMGN','APH','APC','ADI','ANDV',
		'ANSS','ANTM','AON','AOS','APA','AIV','AAPL','AMAT','APTV','ADM','ARNC',
		'AJG','AIZ','T','ADSK','ADP','AZO','AVB','AVY','BHGE','BLL','BAC','BK',
		'BAX','BBT','BDX','BRK.B','BBY','BIIB','BLK','HRB','BA','BWA','BXP','BSX',
		'BHF','BMY','AVGO','BF.B','CHRW','CA','COG','CDNS','CPB','COF','CAH','CBOE',
		'KMX','CCL','CAT','CBG','CBS','CELG','CNC','CNP','CTL','CERN','CF','SCHW',
		'CHTR','CHK','CVX','CMG','CB','CHD','CI','XEC','CINF','CTAS','CSCO','C','CFG',
		'CTXS','CLX','CME','CMS','KO','CTSH','CL','CMCSA','CMA','CAG','CXO','COP',
		'ED','STZ','COO','GLW','COST','COTY','CCI','CSRA','CSX','CMI','CVS','DHI',
		'DHR','DRI','DVA','DE','DAL','XRAY','DVN','DLR','DFS','DISCA','DISCK','DISH',
		'DG','DLTR','D','DOV','DWDP','DPS','DTE','DRE','DUK','DXC','ETFC','EMN','ETN',
		'EBAY','ECL','EIX','EW','EA','EMR','ETR','EVHC','EOG','EQT','EFX','EQIX','EQR',
		'ESS','EL','ES','RE','EXC','EXPE','EXPD','ESRX','EXR','XOM','FFIV','FB','FAST',
		'FRT','FDX','FIS','FITB','FE','FISV','FLIR','FLS','FLR','FMC','FL','F','FTV',
		'FBHS','BEN','FCX','GPS','GRMN','IT','GD','GE','GGP','GIS','GM','GPC','GILD',
		'GPN','GS','GT','GWW','HAL','HBI','HOG','HRS','HIG','HAS','HCA','HCP','HP','HSIC',
		'HSY','HES','HPE','HLT','HOLX','HD','HON','HRL','HST','HPQ','HUM','HBAN','HII',
		'IDXX','INFO','ITW','ILMN','IR','INTC','ICE','IBM','INCY','IP','IPG','IFF','INTU',
		'ISRG','IVZ','IQV','IRM','JEC','JBHT','SJM','JNJ','JCI','JPM','JNPR','KSU','K','KEY',
		'KMB','KIM','KMI','KLAC','KSS','KHC','KR','LB','LLL','LH','LRCX','LEG','LEN','LUK',
		'LLY','LNC','LKQ','LMT','L','LOW','LYB','MTB','MAC','M','MRO','MPC','MAR','MMC','MLM',
		'MAS','MA','MAT','MKC','MCD','MCK','MDT','MRK','MET','MTD','MGM','KORS','MCHP','MU',
		'MSFT','MAA','MHK','TAP','MDLZ','MON','MNST','MCO','MS','MOS','MSI','MYL','NDAQ',
		'NOV','NAVI','NTAP','NFLX','NWL','NFX','NEM','NWSA','NWS','NEE','NLSN','NKE','NI',
		'NBL','JWN','NSC','NTRS','NOC','NCLH','NRG','NUE','NVDA','ORLY','OXY','OMC','OKE',
		'ORCL','PCAR','PKG','PH','PDCO','PAYX','PYPL','PNR','PBCT','PEP','PKI','PRGO','PFE',
		'PCG','PM','PSX','PNW','PXD','PNC','RL','PPG','PPL','PX','PCLN','PFG','PG','PGR',
		'PLD','PRU','PEG','PSA','PHM','PVH','QRVO','PWR','QCOM','DGX','RRC','RJF','RTN','O',
		'RHT','REG','REGN','RF','RSG','RMD','RHI','ROK','COL','ROP','ROST','RCL','CRM','SBAC',
		'SCG','SLB','SNI','STX','SEE','SRE','SHW','SIG','SPG','SWKS','SLG','SNA','SO','LUV',
		'SPGI','SWK','SBUX','STT','SRCL','SYK','STI','SYMC','SYF','SNPS','SYY','TROW','TPR',
		'TGT','TEL','FTI','TXN','TXT','TMO','TIF','TWX','TJX','TMK','TSS','TSCO','TDG','TRV',
		'TRIP','FOXA','FOX','TSN','UDR','ULTA','USB','UAA','UA','UNP','UAL','UNH','UPS','URI',
		'UTX','UHS','UNM','VFC','VLO','VAR','VTR','VRSN','VRSK','VZ','VRTX','VIAB','V','VNO',
		'VMC','WMT','WBA','DIS','WM','WAT','WEC','WFC','HCN','WDC','WU','WRK','WY','WHR','WMB',
		'WLTW','WYN','WYNN','XEL','XRX','XLNX','XL','XYL','YUM','ZBH','ZION','ZTS']
	return stocks_list
def get_comments(comment_list):
     html = requests.get(f'https://api.pushshift.io/reddit/comment/search?ids={comment_list}&fields=body&size=1000')
     newcomments = html.json()
     return newcomments
def get_stock_list(newcomments,stocks_list):
      stock_dict = Counter()
      for a in newcomments['data']:
            for ticker in stocks_list:
                if ticker in a['body']:
                    stock_dict[ticker]+=1
      return stock_dict
def grab_stock_count(stock_dict,raw_comment_list,stocks_list):
     orig_list = np.array(raw_comment_list['data'])
     comment_list = ",".join(orig_list[0:1000])
     remove_me = slice(0,1000)
     cleaned = np.delete(orig_list, remove_me)
     i = 0
     while i < len(cleaned):
        print(len(cleaned))
        cleaned = np.delete(cleaned, remove_me)
        new_comments_list = ",".join(cleaned[0:1000])
        newcomments = get_comments(new_comments_list)
        get_stock_list(newcomments,stocks_list)
     stock = dict(stock_dict)
     return stock
if __name__ == "__main__":
    driver = grab_html()
    stock_link = grab_link(driver)
    comment_id_list= grab_commentid_list(stock_link)
    stockslist = grab_stocklist()
    newcomments = get_comments(comment_id_list)
    stock_dict = get_stock_list(newcomments,stockslist)
    stock = grab_stock_count(stock_dict,newcomments,stockslist)
# Out:
# C:\Users\INTEL\AppData\Local\Temp\ipykernel_14764\767550266.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'c:\chromedriver.exe')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 112
#     110 if __name__ == "__main__":
#     111     driver = grab_html()
# --> 112     stock_link = grab_link(driver)
#     113     comment_id_list= grab_commentid_list(stock_link)
#     114     stockslist = grab_stocklist()
#
# Cell In[2], line 17, in grab_link(driver)
#      15 def grab_link(driver):
#      16 	yesterday =datetime.date.today()-timedelta(days=2)
# ---> 17 	links =driver.links =driver.find_elements_by_xpath('//*[@class="_eYtD2XCVieq6emjKBH3m"]')
#      19 	for a in links:
#      20 		print(a.text)
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_xpath'

# %% [markdown]
# ### Output the data as csv

# %%
import csv
data = list(zip(sorted(stock.keys()),sorted(stock.values())))
with open('stock.csv','w') as w:
    writer = csv.writer(w, lineterminator='\n')
    writer.writerow(['Stock','Number of Mentions'])
    for a in data:
       writer.writerow(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import csv
# ----> 2 data = list(zip(sorted(stock.keys()),sorted(stock.values())))
#       3 with open('stock.csv','w') as w:
#       4     writer = csv.writer(w, lineterminator='\n')
#
# NameError: name 'stock' is not defined

# %% [markdown]
# # Scraping for S&P500

# %%
from datetime import datetime
from concurrent import futures

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web

def download_stock(stock):
	""" try to query the iex for a stock, if failed note with print """
	try:
		print(stock)
		stock_df = web.DataReader(stock,'iex', start_time, now_time)
		stock_df['Name'] = stock
		output_name = stock + '_data.csv'
		stock_df.to_csv(output_name)
	except:
		bad_names.append(stock)
		print('bad: %s' % (stock))

if __name__ == '__main__':

	""" set the download window """
	now_time = datetime.now()
	start_time = datetime(now_time.year - 5, now_time.month , now_time.day)

	""" list of s_anp_p companies """
	s_and_p = ['MMM','ABT','ABBV','ACN','ATVI','AYI','ADBE','AMD','AAP','AES','AET',
		'AMG','AFL','A','APD','AKAM','ALK','ALB','ARE','ALXN','ALGN','ALLE',
		'AGN','ADS','LNT','ALL','GOOGL','GOOG','MO','AMZN','AEE','AAL','AEP',
		'AXP','AIG','AMT','AWK','AMP','ABC','AME','AMGN','APH','APC','ADI','ANDV',
		'ANSS','ANTM','AON','AOS','APA','AIV','AAPL','AMAT','APTV','ADM','ARNC',
		'AJG','AIZ','T','ADSK','ADP','AZO','AVB','AVY','BHGE','BLL','BAC','BK',
		'BAX','BBT','BDX','BRK.B','BBY','BIIB','BLK','HRB','BA','BWA','BXP','BSX',
		'BHF','BMY','AVGO','BF.B','CHRW','CA','COG','CDNS','CPB','COF','CAH','CBOE',
		'KMX','CCL','CAT','CBG','CBS','CELG','CNC','CNP','CTL','CERN','CF','SCHW',
		'CHTR','CHK','CVX','CMG','CB','CHD','CI','XEC','CINF','CTAS','CSCO','C','CFG',
		'CTXS','CLX','CME','CMS','KO','CTSH','CL','CMCSA','CMA','CAG','CXO','COP',
		'ED','STZ','COO','GLW','COST','COTY','CCI','CSRA','CSX','CMI','CVS','DHI',
		'DHR','DRI','DVA','DE','DAL','XRAY','DVN','DLR','DFS','DISCA','DISCK','DISH',
		'DG','DLTR','D','DOV','DWDP','DPS','DTE','DRE','DUK','DXC','ETFC','EMN','ETN',
		'EBAY','ECL','EIX','EW','EA','EMR','ETR','EVHC','EOG','EQT','EFX','EQIX','EQR',
		'ESS','EL','ES','RE','EXC','EXPE','EXPD','ESRX','EXR','XOM','FFIV','FB','FAST',
		'FRT','FDX','FIS','FITB','FE','FISV','FLIR','FLS','FLR','FMC','FL','F','FTV',
		'FBHS','BEN','FCX','GPS','GRMN','IT','GD','GE','GGP','GIS','GM','GPC','GILD',
		'GPN','GS','GT','GWW','HAL','HBI','HOG','HRS','HIG','HAS','HCA','HCP','HP','HSIC',
		'HSY','HES','HPE','HLT','HOLX','HD','HON','HRL','HST','HPQ','HUM','HBAN','HII',
		'IDXX','INFO','ITW','ILMN','IR','INTC','ICE','IBM','INCY','IP','IPG','IFF','INTU',
		'ISRG','IVZ','IQV','IRM','JEC','JBHT','SJM','JNJ','JCI','JPM','JNPR','KSU','K','KEY',
		'KMB','KIM','KMI','KLAC','KSS','KHC','KR','LB','LLL','LH','LRCX','LEG','LEN','LUK',
		'LLY','LNC','LKQ','LMT','L','LOW','LYB','MTB','MAC','M','MRO','MPC','MAR','MMC','MLM',
		'MAS','MA','MAT','MKC','MCD','MCK','MDT','MRK','MET','MTD','MGM','KORS','MCHP','MU',
		'MSFT','MAA','MHK','TAP','MDLZ','MON','MNST','MCO','MS','MOS','MSI','MYL','NDAQ',
		'NOV','NAVI','NTAP','NFLX','NWL','NFX','NEM','NWSA','NWS','NEE','NLSN','NKE','NI',
		'NBL','JWN','NSC','NTRS','NOC','NCLH','NRG','NUE','NVDA','ORLY','OXY','OMC','OKE',
		'ORCL','PCAR','PKG','PH','PDCO','PAYX','PYPL','PNR','PBCT','PEP','PKI','PRGO','PFE',
		'PCG','PM','PSX','PNW','PXD','PNC','RL','PPG','PPL','PX','PCLN','PFG','PG','PGR',
		'PLD','PRU','PEG','PSA','PHM','PVH','QRVO','PWR','QCOM','DGX','RRC','RJF','RTN','O',
		'RHT','REG','REGN','RF','RSG','RMD','RHI','ROK','COL','ROP','ROST','RCL','CRM','SBAC',
		'SCG','SLB','SNI','STX','SEE','SRE','SHW','SIG','SPG','SWKS','SLG','SNA','SO','LUV',
		'SPGI','SWK','SBUX','STT','SRCL','SYK','STI','SYMC','SYF','SNPS','SYY','TROW','TPR',
		'TGT','TEL','FTI','TXN','TXT','TMO','TIF','TWX','TJX','TMK','TSS','TSCO','TDG','TRV',
		'TRIP','FOXA','FOX','TSN','UDR','ULTA','USB','UAA','UA','UNP','UAL','UNH','UPS','URI',
		'UTX','UHS','UNM','VFC','VLO','VAR','VTR','VRSN','VRSK','VZ','VRTX','VIAB','V','VNO',
		'VMC','WMT','WBA','DIS','WM','WAT','WEC','WFC','HCN','WDC','WU','WRK','WY','WHR','WMB',
		'WLTW','WYN','WYNN','XEL','XRX','XLNX','XL','XYL','YUM','ZBH','ZION','ZTS']

	bad_names =[] #to keep track of failed queries

	"""here we use the concurrent.futures module's ThreadPoolExecutor
		to speed up the downloads buy doing them in parallel
		as opposed to sequentially """

	#set the maximum thread number
	max_workers = 50

	workers = min(max_workers, len(s_and_p)) #in case a smaller number of stocks than threads was passed in
	with futures.ThreadPoolExecutor(workers) as executor:
		res = executor.map(download_stock, s_and_p)


	""" Save failed queries to a text file to retry """
	if len(bad_names) > 0:
		with open('failed_queries.txt','w') as outfile:
			for name in bad_names:
				outfile.write(name+'\n')

	#timing:
	finish_time = datetime.now()
	duration = finish_time - now_time
	minutes, seconds = divmod(duration.seconds, 60)
	print('getSandP_threaded.py')
	print(f'The threaded script took {minutes} minutes and {seconds} seconds to run.')
	#The threaded script took 0 minutes and 31 seconds to run.
# Out:
# MMMABT
# bad: ABT
#
# bad: MMM
# ABBV
# bad: ABBV
# ACN
# bad: ACN
# ATVI
# bad: ATVI
# AYI
# bad: AYI
# ADBE
# bad: ADBE
# AMD
# bad: AMD
# AAP
# bad: AAP
# AES
# bad: AES
# AET
# bad: AET
# AMG
# bad: AMG
# AFL
# bad: AFL
# A
# bad: A
# APD
# bad: APD
# AKAM
# bad: AKAM
# ALK
# bad: ALK
# ALB
# bad: ALB
# ARE
# bad: ARE
# ALXN
# bad: ALXN
# ALGN
# bad: ALGN
# ALLE
# bad: ALLE
# AGN
# bad: AGN
# ADS
# bad: ADS
# LNT
# bad: LNT
# ALL
# bad: ALL
# GOOGL
# bad: GOOGL
# GOOG
# bad: GOOG
# MO
# bad: MO
# AMZN
# bad: AMZN
# AEE
# bad: AEE
# AAL
# bad: AAL
# AEP
# bad: AEP
# AXP
# bad: AXP
# AIG
# bad: AIG
# AMT
# bad: AMT
# AWK
# bad: AWK
# AMP
# bad: AMP
# ABC
# bad: ABC
# AME
# bad: AME
# AMGN
# bad: AMGN
# APH
# bad: APH
# APC
# bad: APC
# ADI
# bad: ADI
# ANDV
# bad: ANDV
# ANSS
# bad: ANSS
# ANTM
# bad: ANTM
# AON
# bad: AON
# AOS
# bad: AOS
# APA
# bad: APA
# AIV
# bad: AIV
# AAPL
# bad: AAPL
# AMAT
# bad: AMAT
# APTV
# bad: APTV
# ADM
# bad: ADM
# ARNC
# bad: ARNC
# AJG
# bad: AJG
# AIZ
# bad: AIZ
# T
# bad: T
# ADSK
# bad: ADSK
# ADP
# bad: ADP
# AZO
# bad: AZO
# AVB
# bad: AVB
# AVY
# bad: AVY
# BHGE
# bad: BHGE
# BLL
# bad: BLL
# BAC
# bad: BAC
# BK
# bad: BK
# BAX
# bad: BAX
# BBT
# bad: BBT
# BDX
# bad: BDX
# BRK.B
# bad: BRK.B
# BBY
# bad: BBY
# BIIB
# bad: BIIB
# BLK
# bad: BLK
# HRB
# bad: HRB
# BA
# bad: BA
# BWA
# bad: BWA
# BXP
# bad: BXP
# BSX
# bad: BSX
# BHF
# bad: BHF
# BMY
# bad: BMY
# AVGO
# bad: AVGO
# BF.B
# bad: BF.B
# CHRW
# bad: CHRW
# CA
# bad: CA
# COG
# bad: COG
# CDNS
# bad: CDNS
# CPB
# bad: CPB
# COF
# bad: COF
# CAH
# bad: CAH
# CBOE
# bad: CBOE
# KMX
# bad: KMX
# CCL
# bad: CCL
# CAT
# bad: CAT
# CBG
# bad: CBG
# CBS
# bad: CBS
# CELG
# bad: CELG
# CNC
# bad: CNC
# CNP
# bad: CNP
# CTL
# bad: CTL
# CERN
# bad: CERN
# CF
# bad: CF
# SCHW
# bad: SCHW
# CHTR
# bad: CHTR
# CHK
# bad: CHK
# CVX
# bad: CVX
# CMG
# bad: CMG
# CB
# bad: CB
# CHD
# bad: CHD
# CI
# bad: CI
# XEC
# bad: XEC
# CINF
# bad: CINF
# CTAS
# bad: CTAS
# CSCO
# bad: CSCO
# C
# bad: C
# CFG
# bad: CFG
# CTXS
# bad: CTXS
# CLX
# bad: CLX
# CME
# bad: CME
# CMS
# bad: CMS
# KO
# bad: KO
# CTSH
# bad: CTSH
# CL
# bad: CL
# CMCSA
# bad: CMCSA
# CMA
# bad: CMA
# CAG
# bad: CAG
# CXO
# bad: CXO
# COP
# bad: COP
# ED
# bad: ED
# STZ
# bad: STZ
# COO
# bad: COO
# GLW
# bad: GLW
# COST
# bad: COST
# COTY
# bad: COTY
# CCI
# bad: CCI
# CSRA
# bad: CSRA
# CSX
# bad: CSX
# CMI
# bad: CMI
# CVS
# bad: CVS
# DHI
# bad: DHI
# DHR
# bad: DHR
# DRI
# bad: DRI
# DVA
# bad: DVA
# DE
# bad: DE
# DAL
# bad: DAL
# XRAY
# bad: XRAY
# DVN
# bad: DVN
# DLR
# bad: DLR
# DFS
# bad: DFS
# DISCA
# bad: DISCA
# DISCK
# bad: DISCK
# DISH
# bad: DISH
# DG
# bad: DG
# DLTR
# bad: DLTR
# D
# bad: D
# DOV
# bad: DOV
# DWDP
# bad: DWDP
# DPS
# bad: DPS
# DTE
# bad: DTE
# DRE
# bad: DRE
# DUK
# bad: DUK
# DXC
# bad: DXC
# ETFC
# bad: ETFC
# EMN
# bad: EMN
# ETN
# bad: ETN
# EBAY
# bad: EBAY
# ECL
# bad: ECL
# EIX
# bad: EIX
# EW
# bad: EW
# EA
# bad: EA
# EMR
# bad: EMR
# ETR
# bad: ETR
# EVHC
# bad: EVHC
# EOG
# bad: EOG
# EQT
# bad: EQT
# EFX
# bad: EFX
# EQIX
# bad: EQIX
# EQR
# bad: EQR
# ESS
# bad: ESS
# EL
# bad: EL
# ES
# bad: ES
# RE
# bad: RE
# EXC
# bad: EXC
# EXPE
# bad: EXPE
# EXPD
# bad: EXPD
# ESRX
# bad: ESRX
# EXR
# bad: EXR
# XOM
# bad: XOM
# FFIV
# bad: FFIV
# FB
# bad: FB
# FAST
# bad: FAST
# FRT
# bad: FRT
# FDX
# bad: FDX
# FIS
# bad: FIS
# FITB
# bad: FITB
# FE
# bad: FE
# FISV
# bad: FISV
# FLIR
# bad: FLIR
# FLS
# bad: FLS
# FLR
# bad: FLR
# FMC
# bad: FMC
# FL
# bad: FL
# F
# bad: F
# FTV
# bad: FTV
# FBHS
# bad: FBHS
# BEN
# bad: BEN
# FCX
# bad: FCX
# GPS
# bad: GPS
# GRMN
# bad: GRMN
# IT
# bad: IT
# GD
# bad: GD
# GE
# bad: GE
# GGP
# bad: GGP
# GIS
# bad: GIS
# GM
# bad: GM
# GPC
# bad: GPC
# GILD
# bad: GILD
# GPN
# bad: GPN
# GS
# bad: GS
# GT
# bad: GT
# GWW
# bad: GWW
# HAL
# bad: HAL
# HBI
# bad: HBI
# HOG
# bad: HOG
# HRS
# bad: HRS
# HIG
# bad: HIG
# HAS
# bad: HAS
# HCA
# bad: HCA
# HCP
# bad: HCP
# HP
# bad: HP
# HSIC
# bad: HSIC
# HSY
# bad: HSY
# HES
# bad: HES
# HPE
# bad: HPE
# HLT
# bad: HLT
# HOLX
# bad: HOLX
# HD
# bad: HD
# HON
# bad: HON
# HRL
# bad: HRL
# HST
# bad: HST
# HPQ
# bad: HPQ
# HUM
# bad: HUM
# HBAN
# bad: HBAN
# HII
# bad: HII
# IDXX
# bad: IDXX
# INFO
# bad: INFO
# ITW
# bad: ITW
# ILMN
# bad: ILMN
# IR
# bad: IR
# INTC
# bad: INTC
# ICE
# bad: ICE
# IBM
# bad: IBM
# INCY
# bad: INCY
# IP
# bad: IP
# IPG
# bad: IPG
# IFF
# bad: IFF
# INTU
# bad: INTU
# ISRG
# bad: ISRG
# IVZ
# bad: IVZ
# IQV
# bad: IQV
# IRM
# bad: IRM
# JEC
# bad: JEC
# JBHT
# bad: JBHT
# SJM
# bad: SJM
# JNJ
# bad: JNJ
# JCI
# bad: JCI
# JPM
# bad: JPM
# JNPR
# bad: JNPR
# KSU
# bad: KSU
# K
# bad: K
# KEY
# bad: KEY
# KMB
# bad: KMB
# KIM
# bad: KIM
# KMI
# bad: KMI
# KLAC
# bad: KLAC
# KSS
# bad: KSS
# KHC
# bad: KHC
# KR
# bad: KR
# LB
# bad: LB
# LLL
# bad: LLL
# LH
# bad: LH
# LRCX
# bad: LRCX
# LEG
# bad: LEG
# LEN
# bad: LEN
# LUK
# bad: LUK
# LLY
# bad: LLY
# LNC
# bad: LNC
# LKQ
# bad: LKQ
# LMT
# bad: LMT
# L
# bad: L
# LOW
# bad: LOW
# LYB
# bad: LYB
# MTB
# bad: MTB
# MAC
# bad: MAC
# M
# bad: M
# MRO
# bad: MRO
# MPC
# bad: MPC
# MAR
# bad: MAR
# MMC
# bad: MMC
# MLM
# bad: MLM
# MAS
# bad: MAS
# MA
# bad: MA
# MAT
# bad: MAT
# MKC
# bad: MKC
# MCD
# bad: MCD
# MCK
# bad: MCK
# MDT
# bad: MDT
# MRK
# bad: MRK
# MET
# bad: MET
# MTD
# bad: MTD
# MGM
# bad: MGM
# KORS
# bad: KORS
# MCHP
# bad: MCHP
# MU
# bad: MU
# MSFT
# bad: MSFT
# MAA
# bad: MAA
# MHK
# bad: MHK
# TAP
# bad: TAP
# MDLZ
# bad: MDLZ
# MON
# bad: MON
# MNST
# bad: MNST
# MCO
# bad: MCO
# MS
# bad: MS
# MOS
# bad: MOS
# MSI
# bad: MSI
# MYL
# bad: MYL
# NDAQ
# bad: NDAQ
# NOV
# bad: NOV
# NAVI
# bad: NAVI
# NTAP
# bad: NTAP
# NFLX
# bad: NFLX
# NWL
# bad: NWL
# NFX
# bad: NFX
# NEM
# bad: NEM
# NWSA
# bad: NWSA
# NWS
# bad: NWS
# NEE
# bad: NEE
# NLSN
# bad: NLSN
# NKE
# bad: NKE
# NI
# bad: NI
# NBL
# bad: NBL
# JWN
# bad: JWN
# NSC
# bad: NSC
# NTRS
# bad: NTRS
# NOC
# bad: NOC
# NCLH
# bad: NCLH
# NRG
# bad: NRG
# NUE
# bad: NUE
# NVDA
# bad: NVDA
# ORLY
# bad: ORLY
# OXY
# bad: OXY
# OMC
# bad: OMC
# OKE
# bad: OKE
# ORCL
# bad: ORCL
# PCAR
# bad: PCAR
# PKG
# bad: PKG
# PH
# bad: PH
# PDCO
# bad: PDCO
# PAYX
# bad: PAYX
# PYPL
# bad: PYPL
# PNR
# bad: PNR
# PBCT
# bad: PBCT
# PEP
# bad: PEP
# PKI
# bad: PKI
# PRGO
# bad: PRGO
# PFE
# bad: PFE
# PCG
# bad: PCG
# PM
# bad: PM
# PSX
# bad: PSX
# PNW
# bad: PNW
# PXD
# bad: PXD
# PNC
# bad: PNC
# RL
# bad: RL
# PPG
# bad: PPG
# PPL
# bad: PPL
# PX
# bad: PX
# PCLN
# bad: PCLN
# PFG
# bad: PFG
# PG
# bad: PG
# PGR
# bad: PGR
# PLD
# bad: PLD
# PRU
# bad: PRU
# PEG
# bad: PEG
# PSA
# bad: PSA
# PHM
# bad: PHM
# PVH
# bad: PVH
# QRVO
# bad: QRVO
# PWR
# bad: PWR
# QCOM
# bad: QCOM
# DGX
# bad: DGX
# RRC
# bad: RRC
# RJF
# bad: RJF
# RTN
# bad: RTN
# O
# bad: O
# RHT
# bad: RHT
# REG
# bad: REG
# REGN
# bad: REGN
# RF
# bad: RF
# RSG
# bad: RSG
# RMD
# bad: RMD
# RHI
# bad: RHI
# ROK
# bad: ROK
# COL
# bad: COL
# ROP
# bad: ROP
# ROST
# bad: ROST
# RCL
# bad: RCL
# CRM
# bad: CRM
# SBAC
# bad: SBAC
# SCG
# bad: SCG
# SLB
# bad: SLB
# SNI
# bad: SNI
# STX
# bad: STX
# SEE
# bad: SEE
# SRE
# bad: SRE
# SHW
# bad: SHW
# SIG
# bad: SIG
# SPG
# bad: SPG
# SWKS
# bad: SWKS
# SLG
# bad: SLG
# SNA
# bad: SNA
# SO
# bad: SO
# LUV
# bad: LUV
# SPGI
# bad: SPGI
# SWK
# bad: SWK
# SBUX
# bad: SBUX
# STT
# bad: STT
# SRCL
# bad: SRCL
# SYK
# bad: SYK
# STI
# bad: STI
# SYMC
# bad: SYMC
# SYF
# bad: SYF
# SNPS
# bad: SNPS
# SYY
# bad: SYY
# TROW
# bad: TROW
# TPR
# bad: TPR
# TGT
# bad: TGT
# TEL
# bad: TEL
# FTI
# bad: FTI
# TXN
# bad: TXN
# TXT
# bad: TXT
# TMO
# bad: TMO
# TIF
# bad: TIF
# TWX
# bad: TWX
# TJX
# bad: TJX
# TMK
# bad: TMK
# TSS
# bad: TSS
# TSCO
# bad: TSCO
# TDG
# bad: TDG
# TRV
# bad: TRV
# TRIP
# bad: TRIP
# FOXA
# bad: FOXA
# FOX
# bad: FOX
# TSN
# bad: TSN
# UDR
# bad: UDR
# ULTA
# bad: ULTA
# USB
# bad: USB
# UAA
# bad: UAA
# UA
# bad: UA
# UNP
# bad: UNP
# UAL
# bad: UAL
# UNH
# bad: UNH
# UPS
# bad: UPS
# URI
# bad: URI
# UTX
# bad: UTX
# UHS
# bad: UHS
# UNM
# bad: UNM
# VFC
# bad: VFC
# VLO
# bad: VLO
# VAR
# bad: VAR
# VTR
# bad: VTR
# VRSN
# bad: VRSN
# VRSK
# bad: VRSK
# VZ
# bad: VZ
# VRTX
# bad: VRTX
# VIAB
# bad: VIAB
# V
# bad: V
# VNO
# bad: VNO
# VMC
# bad: VMC
# WMT
# bad: WMT
# WBA
# bad: WBA
# DIS
# bad: DIS
# WM
# bad: WM
# WAT
# bad: WAT
# WEC
# bad: WEC
# WFC
# bad: WFC
# HCN
# bad: HCN
# WDC
# bad: WDC
# WU
# bad: WU
# WRK
# bad: WRK
# WY
# bad: WY
# WHR
# bad: WHR
# WMB
# bad: WMB
# WLTW
# bad: WLTW
# WYN
# bad: WYN
# WYNN
# bad: WYNN
# XEL
# bad: XEL
# XRX
# bad: XRX
# XLNX
# bad: XLNX
# XL
# bad: XL
# XYL
# bad: XYL
# YUM
# bad: YUM
# ZBH
# bad: ZBH
# ZION
# bad: ZION
# ZTS
# bad: ZTS
# getSandP_threaded.py
# The threaded script took 0 minutes and 0 seconds to run.
